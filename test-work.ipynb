# %% [markdown]
# <a href="https://www.kaggle.com/code/aleksandrmorozov123/test-work?scriptVersionId=197968564" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/house-plans/5.jpg
# /kaggle/input/house-plans/1.jpg
# /kaggle/input/house-plans/4.jpg
# /kaggle/input/house-plans/3.jpg
# /kaggle/input/house-plans/2.jpg
# /kaggle/input/house-plans/ROBIN/ROBIN/Dataset_3rooms/Cat14_1.jpg
# /kaggle/input/house-plans/ROBIN/ROBIN/Dataset_3rooms/Cat16_9.jpg
# /kaggle/input/house-plans/ROBIN/ROBIN/Dataset_3rooms/Cat7_10.jpg
# /kaggle/input/house-plans/ROBIN/ROBIN/Dataset_3rooms/Cat11_7.jpg
# /kaggle/input/house-plans/ROBIN/ROBIN/Dataset_3rooms/Cat9_8.jpg
# /kaggle/input/house-plans/ROBIN/ROBIN/Dataset_3rooms/Cat2_3.jpg
# /kaggle/input/house-plans/ROBIN/ROBIN/Dataset_3rooms/Cat1_6.jpg
# /kaggle/input/house-plans/ROBIN/ROBIN/Dataset_3rooms/Cat9_4.jpg
# /kaggle/input/house-plans/ROBIN/ROBIN/Dataset_3rooms/Cat11_10.jpg
# /kaggle/input/house-plans/ROBIN/ROBIN/Dataset_3rooms/Cat17_2.jpg
# /kaggle/input/house-plans/ROBIN/ROBIN/Dataset_3rooms/Cat1_1.jpg
# /kaggle/input/house-plans/ROBIN/ROBIN/Dataset_3rooms/Cat12_4.jpg
# ...

# %%
# !pip install inference-sdk
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 kB 6.0 MB/s eta 0:00:00
# ...

# %%
# we have model from Roboflow Universe for detect house plans
from inference_sdk import InferenceHTTPClient

CLIENT = InferenceHTTPClient(
    api_url="https://detect.roboflow.com",
    api_key="3RKaPLl5aBNcAuWi0CaM"
)

result = CLIENT.infer("/kaggle/input/house-plans/ROBIN/ROBIN/Dataset_3rooms/Cat11_1.jpg", model_id="room_test/1")
print (result)
# Out:
# {'inference_id': '8cf7777b-6d4f-413a-87c0-3dae797711aa', 'time': 0.01792042799979754, 'image': {'width': 839, 'height': 1386}, 'predictions': [{'x': 765.0, 'y': 1039.0, 'width': 148.0, 'height': 136.0, 'confidence': 0.8983446359634399, 'class': 'door', 'class_id': 0, 'detection_id': '0ccd82c4-a8b6-48b0-bed7-66b280129a8a'}, {'x': 549.5, 'y': 305.5, 'width': 135.0, 'height': 173.0, 'confidence': 0.8800943493843079, 'class': 'door', 'class_id': 0, 'detection_id': 'dff96645-1452-4539-a787-5b1d2ea2fcb5'}, {'x': 402.5, 'y': 933.5, 'width': 155.0, 'height': 149.0, 'confidence': 0.8654031753540039, 'class': 'door', 'class_id': 0, 'detection_id': '7cc66b89-1a1d-47d4-bdb5-7a3372ea2d16'}, {'x': 723.0, 'y': 1240.0, 'width': 18.0, 'height': 292.0, 'confidence': 0.7941881418228149, 'class': 'wall', 'class_id': 1, 'detection_id': 'a215bac4-e058-4e56-9834-05a7fe206a1b'}, {'x': 346.0, 'y': 1188.0, 'width': 18.0, 'height': 354.0, 'confidence': 0.7820230722427368, 'class': 'wall', 'class_id': 1, 'detec
# ...

# %%
# save output in json file
import json

# Saving to a JSON file
with open('output.json', 'w') as json_file:
    json.dump(result, json_file, indent=4)  # 'indent=4' for pretty printing

# %%
# open the output file
with open('output.json', 'r') as json_file:
    data = json.load(json_file)

print(data)
# Out:
# {'inference_id': '8cf7777b-6d4f-413a-87c0-3dae797711aa', 'time': 0.01792042799979754, 'image': {'width': 839, 'height': 1386}, 'predictions': [{'x': 765.0, 'y': 1039.0, 'width': 148.0, 'height': 136.0, 'confidence': 0.8983446359634399, 'class': 'door', 'class_id': 0, 'detection_id': '0ccd82c4-a8b6-48b0-bed7-66b280129a8a'}, {'x': 549.5, 'y': 305.5, 'width': 135.0, 'height': 173.0, 'confidence': 0.8800943493843079, 'class': 'door', 'class_id': 0, 'detection_id': 'dff96645-1452-4539-a787-5b1d2ea2fcb5'}, {'x': 402.5, 'y': 933.5, 'width': 155.0, 'height': 149.0, 'confidence': 0.8654031753540039, 'class': 'door', 'class_id': 0, 'detection_id': '7cc66b89-1a1d-47d4-bdb5-7a3372ea2d16'}, {'x': 723.0, 'y': 1240.0, 'width': 18.0, 'height': 292.0, 'confidence': 0.7941881418228149, 'class': 'wall', 'class_id': 1, 'detection_id': 'a215bac4-e058-4e56-9834-05a7fe206a1b'}, {'x': 346.0, 'y': 1188.0, 'width': 18.0, 'height': 354.0, 'confidence': 0.7820230722427368, 'class': 'wall', 'class_id': 1, 'detec
# ...

# %% [markdown]
# **Test on images**

# %%
result_1 = CLIENT.infer("/kaggle/input/house-plans/4.jpg", model_id="room_test/1")
print (result)
# Out:
# {'inference_id': '8cf7777b-6d4f-413a-87c0-3dae797711aa', 'time': 0.01792042799979754, 'image': {'width': 839, 'height': 1386}, 'predictions': [{'x': 765.0, 'y': 1039.0, 'width': 148.0, 'height': 136.0, 'confidence': 0.8983446359634399, 'class': 'door', 'class_id': 0, 'detection_id': '0ccd82c4-a8b6-48b0-bed7-66b280129a8a'}, {'x': 549.5, 'y': 305.5, 'width': 135.0, 'height': 173.0, 'confidence': 0.8800943493843079, 'class': 'door', 'class_id': 0, 'detection_id': 'dff96645-1452-4539-a787-5b1d2ea2fcb5'}, {'x': 402.5, 'y': 933.5, 'width': 155.0, 'height': 149.0, 'confidence': 0.8654031753540039, 'class': 'door', 'class_id': 0, 'detection_id': '7cc66b89-1a1d-47d4-bdb5-7a3372ea2d16'}, {'x': 723.0, 'y': 1240.0, 'width': 18.0, 'height': 292.0, 'confidence': 0.7941881418228149, 'class': 'wall', 'class_id': 1, 'detection_id': 'a215bac4-e058-4e56-9834-05a7fe206a1b'}, {'x': 346.0, 'y': 1188.0, 'width': 18.0, 'height': 354.0, 'confidence': 0.7820230722427368, 'class': 'wall', 'class_id': 1, 'detec
# ...

# %%
# save output in json file
import json

# Saving to a JSON file
with open('output1.json', 'w') as json_file:
    json.dump(result, json_file, indent=4)  # 'indent=4' for pretty printing

# %%
# open the output file
with open('output1.json', 'r') as json_file:
    data = json.load(json_file)

print(data)
# Out:
# {'inference_id': '8cf7777b-6d4f-413a-87c0-3dae797711aa', 'time': 0.01792042799979754, 'image': {'width': 839, 'height': 1386}, 'predictions': [{'x': 765.0, 'y': 1039.0, 'width': 148.0, 'height': 136.0, 'confidence': 0.8983446359634399, 'class': 'door', 'class_id': 0, 'detection_id': '0ccd82c4-a8b6-48b0-bed7-66b280129a8a'}, {'x': 549.5, 'y': 305.5, 'width': 135.0, 'height': 173.0, 'confidence': 0.8800943493843079, 'class': 'door', 'class_id': 0, 'detection_id': 'dff96645-1452-4539-a787-5b1d2ea2fcb5'}, {'x': 402.5, 'y': 933.5, 'width': 155.0, 'height': 149.0, 'confidence': 0.8654031753540039, 'class': 'door', 'class_id': 0, 'detection_id': '7cc66b89-1a1d-47d4-bdb5-7a3372ea2d16'}, {'x': 723.0, 'y': 1240.0, 'width': 18.0, 'height': 292.0, 'confidence': 0.7941881418228149, 'class': 'wall', 'class_id': 1, 'detection_id': 'a215bac4-e058-4e56-9834-05a7fe206a1b'}, {'x': 346.0, 'y': 1188.0, 'width': 18.0, 'height': 354.0, 'confidence': 0.7820230722427368, 'class': 'wall', 'class_id': 1, 'detec
# ...
