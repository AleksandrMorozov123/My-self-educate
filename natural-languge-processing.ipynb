# %% [markdown]
# <a href="https://www.kaggle.com/code/aleksandrmorozov123/natural-languge-processing?scriptVersionId=96280662" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/twitter-sentiment-analysis-hatred-speech/train.csv
# /kaggle/input/twitter-sentiment-analysis-hatred-speech/test.csv

# %% [markdown]
# **Natural Language Processing - step by step**

# %%
# import required libraries
import numpy as np
import json
import pandas as pd

# %%
# read the data
df = pd.read_csv ('../input/twitter-sentiment-analysis-hatred-speech/test.csv')
df.head (5)
# Out:
#       id                                              tweet
# 0  31963  #studiolife #aislife #requires #passion #dedic...
# 1  31964   @user #white #supremacists want everyone to s...
# 2  31965  safe ways to heal your #acne!!    #altwaystohe...
# 3  31966  is the hp and the cursed child book up for res...
# 4  31967    3rd #bihday to my amazing, hilarious #nephew...

# %% [markdown]
# **Lowercase**

# %%
df['tweet'] = df['tweet'].apply (lambda x: " ".join (x.lower () for x in x.split ()))
df['tweet']
# Out:
# 0        #studiolife #aislife #requires #passion #dedic...
# 1        @user #white #supremacists want everyone to se...
# 2        safe ways to heal your #acne!! #altwaystoheal ...
# 3        is the hp and the cursed child book up for res...
# 4        3rd #bihday to my amazing, hilarious #nephew e...
#                                ...
# 17192    thought factory: left-right polarisation! #tru...
# 17193    feeling like a mermaid ð #hairflip #neverre...
# 17194    #hillary #campaigned today in #ohio((omg)) &am...
# 17195    happy, at work conference: right mindset leads...
# 17196    my song "so glad" free download! #shoegaze #ne...
# Name: tweet, Length: 17197, dtype: object

# %% [markdown]
# **Remove punctuation**

# %%
df ['tweet'] = df['tweet'].str.replace (r"""[^\w\s]+""","")

df['tweet']
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# 0        studiolife aislife requires passion dedication...
# 1        user white supremacists want everyone to see t...
# 2        safe ways to heal your acne altwaystoheal heal...
# 3        is the hp and the cursed child book up for res...
# 4        3rd bihday to my amazing hilarious nephew eli ...
#                                ...
# 17192    thought factory leftright polarisation trump u...
# 17193    feeling like a mermaid ð hairflip neverready f...
# 17194    hillary campaigned today in ohioomg amp used w...
# 17195    happy at work conference right mindset leads t...
# 17196    my song so glad free download shoegaze newmusi...
# Name: tweet, Length: 17197, dtype: object

# %% [markdown]
# **Removing stop words**

# %%
import nltk
from nltk.corpus import stopwords

# remove stop words
stop = stopwords.words ('english')
df['tweet'] = df['tweet'].apply (lambda x: " ".join (x for x in x.split () if x not in stop))
df['tweet']
# Out:
# 0        studiolife aislife requires passion dedication...
# 1        user white supremacists want everyone see new ...
# 2        safe ways heal acne altwaystoheal healthy healing
# 3        hp cursed child book reservations already yes ...
# 4        3rd bihday amazing hilarious nephew eli ahmir ...
#                                ...
# 17192    thought factory leftright polarisation trump u...
# 17193    feeling like mermaid ð hairflip neverready for...
# 17194    hillary campaigned today ohioomg amp used word...
# 17195    happy work conference right mindset leads cult...
# 17196    song glad free download shoegaze newmusic newsong
# Name: tweet, Length: 17197, dtype: object

# %% [markdown]
# **Tokenizing step**

# %%
from textblob import TextBlob
TextBlob (df['tweet'][3]).words
# Out:
# WordList(['hp', 'cursed', 'child', 'book', 'reservations', 'already', 'yes', 'ððð', 'harrypotter', 'pottermore', 'favorite'])

# %% [markdown]
# **Stemming**

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer ()
df['tweet'][:5].apply (lambda x: " ".join ([st.stem(word) for word in x.split ()]))
# Out:
# 0    studiolif aislif requir passion dedic willpow ...
# 1    user white supremacist want everyon see new â ...
# 2            safe way heal acn altwaystoh healthi heal
# 3    hp curs child book reserv alreadi ye ððð harry...
# 4    3rd bihday amaz hilari nephew eli ahmir uncl d...
# Name: tweet, dtype: object

# %% [markdown]
# **Lemmatizing**

# %%
from textblob import Word

df['tweet'] = df['tweet'].apply (lambda x: " ".join ([Word(word).
                                                     lemmatize () for word in x.split ()]))

df['tweet']
# Out:
# 0        studiolife aislife requires passion dedication...
# 1        user white supremacist want everyone see new â...
# 2         safe way heal acne altwaystoheal healthy healing
# 3        hp cursed child book reservation already yes ð...
# 4        3rd bihday amazing hilarious nephew eli ahmir ...
#                                ...
# 17192    thought factory leftright polarisation trump u...
# 17193    feeling like mermaid ð hairflip neverready for...
# 17194    hillary campaigned today ohioomg amp used word...
# 17195    happy work conference right mindset lead cultu...
# 17196    song glad free download shoegaze newmusic newsong
# Name: tweet, Length: 17197, dtype: object

# %% [markdown]
# **Exploring text data**

# %%
# import required libraries

import nltk
from nltk.corpus import webtext
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import string

# computer the frequency of all words
frequency_dist = nltk.FreqDist (df['tweet'])
frequency_dist
# Out:
# FreqDist({'model love u take u time urð ðððð ððð': 170, 'finally found way delete old tweet might find useful well deletetweets': 43, 'aww yeah good bing bong bing bong': 32, 'im grateful affirmation': 31, 'happy work conference right mindset lead cultureofdevelopment organization work mindset': 31, 'lighttherapy help depression altwaystoheal healthy happy': 27, 'user feminismiscancer feminismisterrorism feminismmuktbharat malevote ignored user': 20, 'might libtard libtard sjw liberal politics': 16, 'ð love instagood photooftheday toptags tbt cute beautiful followme followâ': 16, 'save logins x broker change meme love education university': 14, ...})

# %%
sorted_frequency_dist = sorted (frequency_dist, key = frequency_dist.__getitem__, reverse = True)
sorted_frequency_dist
# Out:
# ['model love u take u time urð ðððð ððð',
#  'finally found way delete old tweet might find useful well deletetweets',
#  'aww yeah good bing bong bing bong',
#  'im grateful affirmation',
#  'happy work conference right mindset lead cultureofdevelopment organization work mindset',
#  'lighttherapy help depression altwaystoheal healthy happy',
#  'user feminismiscancer feminismisterrorism feminismmuktbharat malevote ignored user',
#  'might libtard libtard sjw liberal politics',
#  'ð love instagood photooftheday toptags tbt cute beautiful followme followâ',
#  'save logins x broker change meme love education university',
#  'best essentialoils anxiety healthy peace altwaystoheal',
#  'get get get enjoy music today free apps free music',
#  'lighttherapy help sad depression altwaystoheal healthy',
#  'user might libtard libtard sjw liberal politics',
#  'people arent protesting trump republican wonthey trump fuhered ampâ',
#  '100 amazing health benefit cucumber healthy altwaystoheal',
#  'lover stop angry visit usgtgtgt lover friend astrologer love',
#  'looking feel joy join 20 speaker free summit unleashyourjoy',
#  'food healing body doplants healthy',
#  'use power mind heal body altwaystoheal healthy peace',
#  'user',
#  'sea shepherd suppoers racist antiracism seashepherd',
#  'safe way heal acne altwaystoheal healthy healing',
#  'heal lawofattraction loa altwaystoheal healthy wellness',
#  'thankful love thankful positive',
#  'today perfect day happiness lifecoach reinventimpossible',
#  'lawofattraction healing altwaystoheal healthy',
#  'stuck rat race find freedom masterkeyexperience',
#  'best lawofattraction resource healing altwaystoheal healthy idwp',
#  'atherapy musictherapy heal life altwaystoheal healthy healing',
#  'sta laughing cry make sad laugh cry distressed anxious change mindset depressed',
#  'amp grateful money come increasing quantity multiple source continuous basis',
#  'use power mind heal body altwaystoheal healthy',
#  'love abrahamhicks lawofattraction healthy healing joytrain',
#  'photo accepted user amp sale user photography',
#  'music therapy tool healing altwaystoheal healthy',
#  'herbal sleep remedy work altwaystoheal healthy healing',
#  'user fathersday gift proud dadsavailable 1 day',
#  'cloudchaser bull hill climb reach target complete task survive strong ex',
#  'angry squeaking frog video frog nature animal cute adorable',
#  '',
#  'teen girl killed 3 others injured downtown oakland shooting gun mentalillness gang ðððððð orlando',
#  'save thousand free search x logins x broker actor seeklearning stafresh',
#  'intelligent i_am positive affirmation',
#  'ased bull dominate bull direct whatever want',
#  'best homeopathic remedy anxiety altwaystoheal healing peace',
#  'damn really made tear little mustread',
#  'detoxdiet altwaystoheal healthy',
#  'rssruggedmaxxx love instagood tbt photooftheday cute beautiful follâ',
#  'make',
#  'flowerlove bull dominate bull direct whatever want',
#  'removal aap spokesperson alkalamba showcase dictatorial mindset kejriwal',
#  'broken buffalo simulation buffalo take vicinity home way',
#  'best essentialoils weightloss altwaystoheal healthy',
#  'parente bull dominate bull direct whatever want',
#  'saysomething bull dominate bull direct whatever want',
#  'herbalremedies anxiety work altwaystoheal healthy healing peace',
#  'save date 142017 sourcenation live wed 8 thependulum user newshow policebrutalityâ',
#  'thankful passion thankful positive',
#  'flagday2016 flag day 2016 30 photo buy thing flag day 2016 â',
#  'taylorswift1989 bull dominate bull direct whatever want w',
#  'lawofattraction healing loa healthy well idwp',
#  'green bull hill climb reach target complete task survive strong excitem',
#  'wont spare leader kolianwali meet fate ravisidhu capt amarinder',
#  'user snow white gt open gt sleepy sneezy bashful dm u today',
#  'raw food diet benefit altwaystoheal healthy healing peace joy love',
#  'thrilling i_am positive affirmation',
#  'thankful freedom speech thankful positive',
#  'justinb gorilla simulator need adapt environment need tear city materia',
#  'thankful laughter thankful positive',
#  'user might going hell surprised versace',
#  'zaynmalik bull dominate bull direct whatever want yo',
#  'thankful internet connection thankful positive',
#  'best essential oil healing altwaystoheal healthy',
#  'powerful i_am positive affirmation',
#  'man come last race declared winner putinschoice putinspuppet retweetâ',
#  'magnettherapy really work altwaystoheal healing healthy',
#  'want creative worker give enough time play success quote',
#  'safe i_am positive affirmation',
#  'refined i_am positive affirmation',
#  'springfield bull dominate bull direct whatever want',
#  'lessismore polar bear climb racing angry polar bear climb racing polar bear living cold place l',
#  'black amp feel like stomping listen retweet tampa miamiâ',
#  'cotd polar bear climb racing angry polar bear climb racing polar bear living cold place looking',
#  'smaphone bull dominate bull direct whatever want',
#  'glamorous i_am positive affirmation',
#  'thankful hope thankful positive',
#  'â black amp feel like stomping listen retweet tampa miamiâ',
#  'thankful home thankful positive',
#  '60 powerful minute free podcast anxiety stress life success nowplaying',
#  'facebook attack bull chase leave lot despite fact youre strong source fo',
#  'watch weddingplanning people',
#  'quotesilove polar bear climb racing angry polar bear climb racing polar bear living cold place',
#  'graceful i_am positive affirmation',
#  'spiritualgrowth bull dominate bull direct whatever want w',
#  'nuuring i_am positive affirmation',
#  'user comment reflection ignorance',
#  'sometimes take smile smile via user',
#  'meditation gorilla simulator need adapt environment need tear city mate',
#  'thankful fun thankful positive',
#  'bubbly i_am positive affirmation',
#  'toptweeters like one âvenusexchangeâ â',
#  'thankful able see thankful positive',
#  'introduction happy day day',
#  'haileysporn na sexy shy porn horny nasty naughty slut hot xxx nude wet kinky young',
#  'specially trained officer stop two angry dog without violence video',
#  'trainhard polar bear climb racing angry polar bear climb racing polar bear living cold place lo',
#  'â hispanic amp feel like stomping listen retweet boricuaâ',
#  'tyler perry claim âreverse racismâ critic tlc series tyler perry claim reverse criticsââ',
#  'user tgif ff gamedev indiedev indiegamedev squad user user user user user',
#  'thankful food thankful positive',
#  'newstar bull dominate bull direct whatever want',
#  'elegant i_am positive affirmation',
#  'user 3 key found computer enjoy life inspiration advice',
#  'studio attack bull game 3d really think head empty around city side sup',
#  'film bull dominate bull direct whatever want sta',
#  'lightroom bull dominate bull direct whatever want yo',
#  'book german colonialism global age ht user imperialism blm',
#  'decor buffalo simulation buffalo take vicinity home way',
#  'fathersday comfo zone father day buy thing father day â',
#  'thankful mistake thankful positive',
#  'thankful sunshine thankful positive',
#  'blackcokwhiteass na kinky snapshot naughty nasty porn wet slut horny young shy xxx sexy',
#  'choosing thought choose blessed grateful themoodcards via user',
#  'energetic i_am positive affirmation',
#  'success order',
#  'happy day altwaystoheal healthy',
#  'fabulous i_am positive affirmation',
#  'thankful country thankful positive',
#  'rainbowrowell bull dominate bull direct whatever want whe',
#  'generous i_am positive affirmation',
#  'winterfashion bull dominate bull direct whatever want whe',
#  'hispanic amp feel â stomping listen retweet boricua miamiâ',
#  '13 tip help flourish positivity success growth balance',
#  'contactcenters quality improve fun perk avi ootd result new bestâ',
#  'hispanic amp â like stomping listen retweet boricua miamiâ',
#  'drakeandjosh buffalo simulation buffalo take vicinity home wa',
#  'thankful able learn thankful positive',
#  'ð ð ð love instagood photooftheday toptags tbt cute beautiful followme â',
#  'choose happy matter circumstance free smile',
#  'smilepowerday show u best cheesy grin pearly white smile teeth',
#  'lot resistance challenge favorite thoughtleaders mentor',
#  'thankful forgiveness thankful positive',
#  'user bestseller family motivation never go bed without dream wakeup without hope',
#  'genuine i_am positive affirmation',
#  'respected i_am positive affirmation',
#  'playinggames buffalo simulation buffalo take vicinity home wa',
#  'scribble polar bear climb racing angry polar bear climb racing polar bear living cold place loo',
#  'thankful paner thankful positive',
#  'thriving i_am positive affirmation',
#  'cutemuscleboys na nasty wet hot young slut xxx kinky naughty porn sexy shy horny nude',
#  'tattoosleeves gorilla simulator need adapt environment need tear city',
#  '7 step healthy aging',
#  'mountain rooster simulation want climb vast expanse mountain reached leakage cock',
#  'thankful photograph thankful positive',
#  'nothing make dad happier tasty meal fathersday',
#  'ðthe garden wisdom wisdom saturdaymorning ð flower saterday vine vine user',
#  'nature_perfection bull hill climb reach target complete task survive str',
#  'haford buffalo simulation buffalo take vicinity home way',
#  'thankful new place thankful positive',
#  'quoteoftheday bull dominate bull direct whatever want whe',
#  'cute i_am positive affirmation',
#  'âyou black amp feel like stomping listen retweet tampa miamiâ',
#  'electronic music bogota colombia puntohost cedm edm dj fashion music',
#  'begun something new page amp super daily tarot guidance',
#  'macbook gorilla simulator need adapt environment need tear city materia',
#  'grow old along best yet ârobe browning wedding love',
#  'thankful health thankful positive',
#  'knowing i_am positive affirmation',
#  'tyler ward amp cimorelli cover pharrell williams music video',
#  'user spend life people make user quote inspiration user',
#  '7 step aging healthy',
#  'user father day',
#  'marathon bull dominate bull direct whatever want',
#  'weekend amp ramadan everyone try find dream propey weekend u dubai uae',
#  'user trouble updating blackberry passpo 10 o 10322836 always stop installing 2 2 44 need help',
#  'user finally found way delete old tweet might find useful well deletetweâ',
#  'dazzling i_am positive affirmation',
#  'burlap farmdogs fun dog animal cute funny playing hay',
#  'life make letâs make motivation',
#  'sad dukhi shairi urdu shairi love poetry gazal nice poetry daily free poetry dosti msg plz 1 try follow user snd 40404',
#  'visiting gorilla simulator need adapt environment need tear city materi',
#  'thankful thankful positive',
#  'wedding teaser amp c photography wedding photography bride groom moment',
#  'thankful star thankful positive',
#  'funny thing humankind watch news feel bad etc back open business usual good future',
#  'thankful getting encouragement thankful positive',
#  'thankful good health thankful positive',
#  '11 racist u president user via user america promise equality lie',
#  'fathersday father day columbus post buy thing happy faâ',
#  'cedarrapids bull dominate bull direct whatever want',
#  'make float perfectly',
#  'childhood bull dominate bull direct whatever want yo',
#  'angel archangel high help live spiritual anf life',
#  'thankful school thankful positive',
#  'user blackheathstandard summerfair ð user user user user',
#  'user bihday rg',
#  'sta day cute note setting cuddle alarm much aâ',
#  'thankful parent thankful positive',
#  'fitnessaddict attack bull chase leave lot despite fact youre strong source',
#  'user good morning guy love instagood photooftheday fashion cute summer fun smile',
#  'alreemgroup aly_alshahawy ad cute summer photographerdubai sun hair mydubaiâ',
#  'ryderrideu see c2c cum together snapshot young shy kinky wet porn hot xxx horny',
#  'dentalclinic bangalore wish morning',
#  'ð smile smiling toptags toptags smile beautifulsmile smiley smilee pretty â',
#  'father day',
#  'jesserushot compliment present make horny daddy slut shy sexy snapshot xxx',
#  'people must think good drug really good actor happiness joy flow love',
#  'reality tech industry made regularass people tech discrimination',
#  'anyscott na young nasty nude naughty horny wet sexy porn slut xxx hot kinky snapshot shy',
#  'dog kind way say âdont worry â dogsarejoy',
#  'thankful cloud thankful positive',
#  'samsunggalaxys2 rooster simulation want climb vast expanse mountain reached leakage',
#  'thankful baby giggle thankful positive',
#  'thankful sense smell thankful positive',
#  'select retailer planet organic lemonade save 100 15 l size cashbackoffers',
#  'back view blowoutsbringhappiness yet another client booked appointment user',
#  'acquainted punjabi culture kejriwal trying lure punjabi',
#  'hispanic feel like stomping listen retweet boricuaâ',
#  'itwing play impoant role 2017 poll list officebearers',
#  'sikh temple vandalised calgary wso condemns act',
#  'go germany ó¾ gogermany em em2016 family love germany selfie lovemyfamily smileâ',
#  'let go bitterness get ebook happiness free today',
#  'fathersday father day saying quote image buy thing happy fathâ',
#  'thankful fall leaf thankful positive',
#  'happy picture video webcam picture video',
#  'feel recognizing expressing amp managing anger printable activity color bampw ver',
#  'light i_am positive affirmation',
#  'thought factory leftright polarisation trump uselections2016 leadership politics brexit blm 10',
#  'increase profit hit sale 1 24 tweet day â60â500 worldwide photooftheday beautiful',
#  'user âlearn pursue wantâ user leadership success',
#  'selamatmalam coffee time user thank visiting beautiful long weekendâ',
#  'thankful warm running water thankful positive',
#  'normalization isnt new user via user',
#  'stressed dont lose greatbook amreading relax life',
#  'ashleymorrisx na nude xxx slut nasty wet sexy naughty kinky young hot porn shy horny',
#  'fathersday looking something see whats trending community',
#  'founate i_am positive affirmation',
#  'user user prfectpitch miss episode play back user',
#  'thankful apology thankful positive',
#  'thankful able walk thankful positive',
#  'likescam bull hill climb reach target complete task survive strong excit',
#  'petal polar bear climb racing angry polar bear climb racing polar bear living cold place lookin',
#  'thankful vaccine thankful positive',
#  'thankful friday thankful positive',
#  'attractive i_am positive affirmation',
#  'brittany9 na slut nude sexy naughty horny xxx kinky wet porn snapshot shy nasty hot young',
#  'nice i_am positive affirmation',
#  'make make smile laugh much breathe love long live',
#  'thankful rainbow thankful positive',
#  'thursday everyone wishing sunny day âï amp lot blue sky vine user',
#  'user model love u take u time urð ðððð ððð',
#  'olathe polar bear climb racing angry polar bear climb racing polar bear living cold place looki',
#  'stripe bull dominate bull direct whatever want',
#  'impressive i_am positive affirmation',
#  'regrann user prayfororlando ð regrann',
#  '7 impoant thing allow child',
#  'user user user',
#  'electrifying i_am positive affirmation',
#  'late ff gamedev indiedev indiegamedev squad user user user user',
#  'make overweight dog dog health problem',
#  'feel story recognizing expressing managing anger printable color bampw',
#  'cat photogrid user cuteness eye instasize perfection â',
#  'thankful eyesight thankful positive',
#  'amazing i_am positive affirmation',
#  'user fire provider director editor approved resolution white guy',
#  '11 habit supremely people',
#  'thankful challenge thankful positive',
#  'amazingly talkshow thursday 9pm hifi studio user',
#  'dr france cress welsing racism defined whitesupremacy drfranciscresswelsing',
#  'sensitive fan right xmenapocalypse movie poster',
#  'user back user user user via user',
#  'user wish bihday may god bless happiness joy strength long great year ahead',
#  'goodmorning world rainingday',
#  'founatei_am positive affirmation',
#  'dont count day make day countðð flower friday vine vine user',
#  'user bihday ð',
#  'becoming ugly mt user patriarchy feminist feminism',
#  'thankful freedom vote thankful positive',
#  'eat vegetable dram dram broccoli lilyachty music musicvideo dance lovedance music',
#  'inked polar bear climb racing angry polar bear climb racing polar bear living cold place lookin',
#  'electronic music bogota colombia puntohost edm dj ibiza fashion envivo music live',
#  'adorable i_am positive affirmation',
#  'dont worry',
#  'imaginative i_am positive affirmation',
#  'peppa pig bird lollipop finger family nursery rhyme lyric qua user',
#  'archive thought happiness happiness contentment want blog grateful wonderful',
#  'johnson publishing sell ebony jet magazine texas firm chicago tribune',
#  'thankful app thankful positive',
#  'bob holman man truly walked walk life well lived loss gtgt',
#  'spirited i_am positive affirmation',
#  'like4like likeforlikealways hourstagsforlikes instapicinstagoodinstafashionâ',
#  'morning fighting fashionblogger fashionillustrator fashionillustrationâ',
#  'user toptweeters like one âvenusexchangeâ â',
#  'thankful sense touch thankful positive',
#  'antidepressant ruin ur nat serotonin u never b wo ur pill',
#  'coz vids dont mean woh wotching hilarious must watcâ',
#  'day',
#  'popular i_am positive affirmation',
#  'successful i_am positive affirmation',
#  'life new selfhelp ecourse designed livinghappy inside',
#  'user glass john lennon wore shot killed new york december 81980',
#  'thankful internet thankful positive',
#  'healthy body healthy mind productive hr',
#  'ok i_am positive affirmation',
#  'osu launch divided community project',
#  'user grow old along best yet ârobe browning wedding love',
#  'exercise smile today weekend smile exercise fitness',
#  'new plymouth road location traverwood replaces green road store',
#  'thankful freedom thankful positive',
#  'seek probe udtapunjab leak point finger amarinder aap',
#  'hispanic amp feel like stomping listen retweet boricua miami newyork losangeles',
#  'online sourcing system open talk u live website time broker',
#  'thankful able remember thankful positive',
#  'kid get parenting toddler',
#  'user bestseller inspiration golf never go bed without dream wakeup without hope',
#  'billofmaterials uncover take unleashed dazzling oomf gmr created toolkit â',
#  'happy i_am positive affirmation',
#  'book enduring conviction fred korematsu amp quest justice humanrights htâ',
#  'thankful clean sheet thankful positive',
#  'ransom landlord cat theyd look like join u amp ð exeter',
#  'join essence life wwwface care inspire love quote quoteoftheday suppo',
#  'brave i_am positive affirmation',
#  'gameshow bull hill climb reach target complete task survive strong excit',
#  'black amp feel like â stomping listen retweet tampa miamiâ',
#  'thankful sunday thankful positive',
#  'read dancing make user user user',
#  'user thankful peace thankful positive',
#  'healthy i_am positive affirmation',
#  'nashville tour monday user user user user nashvilleontourð',
#  'rock logo audiojungle soundclip royaltyfreemusic',
#  'original illustration miss sword truth inspired kahlan siâ jankala',
#  'thought factory leftright polarisation trump uselections2016 leadership politics brexit blm 13',
#  'photoshop bull dominate bull direct whatever want yo',
#  'vehicle gorilla simulator need adapt environment need tear city materia',
#  'nigger lifelessons white kid grew 60 blogpost whitepeople respectâ',
#  'korea gorilla simulator need adapt environment need tear city material',
#  'feel childrens story recognizing expressing managing sadness par',
#  'bypo echocide waterislife poetry poem solidarity nodapl climatejustice climatechage epa classwar',
#  'user facebook 22nd rm day 2015 ëëªday btsrmday2015 user',
#  'delaying tactic sit bjp 1984 riot',
#  'magic tidying brenda palmer goodread amazon reading decluttering',
#  '100 amazing health benefit cucumber healthy doplants',
#  'thankful puppy thankful positive',
#  'user little needed make life within way thinking',
#  'thankful farmer farmer market thankful positive',
#  'calm i_am positive affirmation',
#  'thankful rainthankful positive',
#  'born â life purpose god child',
#  'user surprise adam saleh david wood',
#  'fathersday father day craft beer amp kitchencraft beer amp kitchen buy tâ',
#  'simple thankyou take customer marketer socialmedia wahm',
#  'truthful i_am positive affirmation',
#  'user thankful tear thankful positive',
#  'user revolution occurredâjust marx expected â teambts teamsuperjuniorâ',
#  'retweet love healthy brain healthy',
#  'inside home orlando terrorist omar mateen user loser belief fanatic islam culture anger',
#  'want via user joy life time',
#  'dont count day make day count spring memory ð flower vine user',
#  'jacksonville rooster simulation want climb vast expanse mountain reached leakage co',
#  'national iced tea day ó¾ó¾ó¾ celebrating offering delicious blend tea',
#  '10 step sell structuredsettlement read share home write vitorr staup live usa england house',
#  '2play maison johnny user w user user user',
#  'user user',
#  'sirf ashiq log follow karen iqbal galib wasi faraz mohsin ki full poetry add follow user send 4o4o4',
#  'lucky i_am positive affirmation',
#  'studiolife aislife requires passion dedication willpower find newmaterialsâ',
#  'user white supremacist want everyone see new â birdsâ movie â hereâs',
#  'hp cursed child book reservation already yes ððð harrypotter pottermore favorite',
#  '3rd bihday amazing hilarious nephew eli ahmir uncle dave love missesâ',
#  'choose momtips',
#  'something inside dy ððâ eye ness smokeyeyes tired lonely sof grungeâ',
#  'finishedtattooinkedinkloveitâï âïâïâïâï thanksaleeee',
#  'user user user never understand dad left young deep inthefeels',
#  'delicious food lovelife capetown mannaepicure resturantâ',
#  '1000dayswasted narcosis infinite ep make aware grinding neuro bass lifestyle',
#  'one world greatest spoing event lemans24 teamaudi',
#  'half way website allgoingwell',
#  'good food good life enjoy ðððððð called garlic bread iloveitâ',
#  'ill stand behind guncontrolplease senselessshootings taketheguns comicrelief stillsad',
#  'atei ate ateðð jamaisasthi fish curry prawn hilsa foodfestival foodie',
#  'user got user limited edition rain shine set today user user user user',
#  'amp love amp hug amp kiss keep baby parenting healthcare',
#  'ððð girl sun fave london united kingdom',
#  'thought factory bbc neutrality right wing fascism politics medium blm brexit trump leadership gt3',
#  'hey guy tommorow last day exam im happy yay',
#  'user user user levyrroni recuerdos memoriesðâððð recuerdos friend life triunfodelamor',
#  'mind like ððð½ð body like ðððµð½ sleepy stillallinð',
#  'never entire life',
#  'check twitterww trend trending worldwide 1114 bst1 oscarpistorius2 diplomaläliselilerayakta3 â',
#  'thought saw mermaid ceegee smcr inshot girl cute summer blur sun â',
#  'chick get fucked hottest naked lady',
#  'happy bday lucyââð xoxo love beautiful pizza instagood mileycyrus demilovatoâ',
#  'haroldfriday weekend filled sunbeam everyone healthy weekend',
#  'user user tried nothing try know loved 2 3rd light fave ampdeep river',
#  'ill never 120 im im thick woman blacktina',
#  'user new user episode tk really cool 2year anniversary ep work august',
#  'orangechicken attack bull game 3d really think head empty around city side',
#  'suppo taiji fisherman bullying racism tweet4taiji thecove seashepherd',
#  'say im speaking collectively ive always known 2016 showed lot andâ',
#  'wish could talk',
#  'food time haylie ð hot chocolate mummy âïâ ððððªâð thank god friday ððð â',
#  'bihday shilpashetty wish successful yearretailermanufacturer lady cloth',
#  'wasnt lottery',
#  'tomorrow fun seeing old friend shooting something super fun',
#  'user user trump invested billion saudi empowers people funding isi trumpsahypocrite',
#  'granddaughter 1st bihday tomorrow going pick play house little car amp pool today ððððððð',
#  'happiest place eah disneyworld orlando castle mickeymouse likechildrens user',
#  'baby dave due born october 26my fav band time tool playing user weekend lol',
#  'loving every day',
#  'user morning sunshine ð smile sexy bigboobs',
#  'world make jesus make happy john 1633 word truth faith peaceâ',
#  'enjoying sunshine god good orlando sunshinestate goodlife bosslady joy â',
#  'user father idol prg',
#  'user reason maintainer android provide clear basic code example doc',
#  'nice luxuryweekó¾ó¾ monday neweek luxuryweek bestday staypositive fun goodmoments lifestyle',
#  'cause user get live together whole week cantwaittocook ðð',
#  'user user user user throw back thursday bih day 2 brouser chege',
#  'saw shes craying coz baby hard breath strong yeah baby god withâ kaika medical center â',
#  'happened baby duedec2016',
#  'let thing euro2016',
#  'time ðð¼ðð¼ðð¼â½ïâ½ï euro2016 onemonth 24teams onewinner football international 10thjune10thjuly',
#  'good sunday everyone ððððâ½ïð sunday morning smile picofthedayâ',
#  'cousin asking always shawldi ko lang masabi coz po im getting fat braso getting bigger baboy',
#  'believe r willingness 2 try 2 understand 2 encourage amp 2 inspire others 2 b amp grow greater spiritual purpose grok',
#  'time pint seeing coldplay wembleyyyy ð³ðð coldplay wembleystadiumâ',
#  'current mood goodnight happilyeverafter disney quote blessed thankful gratefulâ',
#  'chioma noble igwes special day chobs16 chobs2016 user landmark_centre user',
#  'cant believe left school 5 year ago 8 week time ill teaching class dramateacher gettingold',
#  'lipolight helped shape help shape learn user loseinches burnfat result',
#  'ahhh leaving user tomorrowððð¼ðð user eforest2016 electricforest plur',
#  'blessed hear morning chorus good morning people fridayðð',
#  'aunti mi find hilarious post nigeria enough trouble',
#  'user 6 chapter left book amp nearly complete kruella adaughterstale hard read emotional funnyâ',
#  'user thrilled working user coming month announcement soon 2faceddancecompany',
#  'trying another way make sourdough bread one may underproofed failed baking',
#  'cool old door window 5000 vendor 509 shoplocal shopalyssas fathersday',
#  'fathersday fatherday user team',
#  'greatbritain eye sky rafredarrows fly past mall say â',
#  'user 8000 followerswe blessed love everyone suppos u thx much fishing fâ',
#  'user user user user user lt feeding public trough piggy michelleobamaâ',
#  'website live avon makeup fresh look',
#  'forecast look good weather across bolton',
#  'user happy shootingðââïâðâðð love monicaðð sweet magazine thanku love',
#  'happy father day ððð father day fathersday dad ilovemydad ilovemyfather love',
#  'stardivarius friday new history new outfit post fashion look friendsflâ',
#  'user final countdown official u publication june 1st whyfontsmatter usa typography font book',
#  'happy trusted first knowâð lovelovelovebabies',
#  'interview feat grandmaster flash ze lovely message ââªâââºâº nurap nudisco music paris ââªâ via user',
#  'im getting hour work training im',
#  'life right amazingð successful positive',
#  'social medium reality really get viual acceptance seems really thing ocialmedia',
#  'user ðª seven tomorrowðª southwestseason ðfinalðagainst user next week plus scrim user wearebusy',
#  'user user user user user ignorant amp ill informed tweet r silly childish amp one dimensional',
#  'great see look forward welcoming digme',
#  'jackblair na horny hot naughty nasty slut young shy wet nude xxx sexy porn kinky snapshot',
#  'user user u take pour one big cup drink delivered',
#  'ððððâïððð happy father day dad hope u great day love u ððððâïððð fathersday loveyou',
#  'working anatomy studyguide since 5 pm still done isuck plspassme',
#  'worry daydream sunlight thunder miss dream distance silence pain sweetâ',
#  'user getting ready kubamba father day kambua noel gg moh blessed',
#  'ya know guy feeling stressed donut thing feel happy know 96 follower sticking',
#  'pa 2 åæããã ãã¼ãã¼æ ãã¼ãºã½ããã¹ ããã³ãã¼ã jk ããã ãããªã³ åç ããª fun memory bffð loveâ',
#  'back people missingperson havingfunalone lonely ð hothl ððð',
#  'l v e sky photoofday moment cool instaphoto paradise good mexicoâ',
#  'happy saturday tune _ music saturday edm',
#  'many user alum friend waking shocked hear death scsu president shocked',
#  'user im disappointed yesterday argument wasnt even baselessly accused living mother basement weak bad',
#  'hey user 14000 ivanka bracelet feel good profiting xenophobia misogyny hatred grabyourwallet',
#  'loving saw temporary setup',
#  'happy euro 2016 eve euro2016 ðððªð½ðªð½',
#  'user 741 retweets half day thats gun owner like hubby amp dont respect fanaticism',
#  'colourpop ðððð',
#  'palladino ill say whatâ iâ feel like sayingâ gopathetic lookwhatyoudid politics madcow',
#  'user fursuit fucking hardcore 2008',
#  'something obviously really funny ð laugh girl smile â',
#  'fbf staing far user come amp anxious whatâ',
#  'thankful film thankful positive',
#  'user user user user way oambo see soon sasocp16',
#  'user user user always always always somebody el fault bigot',
#  'turning todayðð½ððð½ð whitegirlwasted dramafree armedsecurityâ',
#  'qatil poetry poetry eid poetry 2 line sm eid ghazal urdu poetry dard poetry beutiful poetry follow user send 4o4o4',
#  'rip victim usa prayfororlando terrorism victim lgbt suppo altogether pride stand',
#  'user read aicle 4 yr even dhabas side national highway growing 12 acre ganja â',
#  'drive see grease amp footloose âºïð',
#  'user thank steve dont think quite sunk though',
#  'user today good day ðhappiestplaceoneah disneyland fun walking sundayfundayâ',
#  'ltpst ðð need vitamin sea ðð beach blue smile',
#  'user today meððððððð code white summer love',
#  'rainbow wall street good way end training officialrainbowspotterâ',
#  'water ð',
#  'going great day day doesnt choice matter feelinggood proud feelingaccomplished motivated',
#  'user oh ton stuff like wont eah garbage dump',
#  'found vault never posted ð selfie throwback boy guy love â',
#  'happy friday wegotwheels car vw polo firstcar ontheroad whitepolo newcarâ',
#  'user together christmas pls amp follow user national day action 20 feb amp theâ',
#  'withasumiðððð yesterday shotdisneydisneyland enjoy',
#  'user game throne s5 longer sky box set mad help',
#  'user straight chaser music video',
#  '4u nonhockey people hockey babe ruth died gordie howe beyond myth legend hockey lost mr hockey',
#  'linkedin anything work giving free membership canadian australian british veteran justusvetsatm',
#  'michelleobama looking bit dishevelled thinking spending retirement visiting obama aâ',
#  'dinner lukey boy ððlovehim holiday orlando clear creek circleâ',
#  'cant wait watch user everyone user evening',
#  'user hahaha thats good point totally skipped youre 14 celebrity dad asking',
#  'cat bagfruit ninja steam htcvive',
#  'user nationalgermanbestfriendday maybe ðððð¼',
#  'really good cooking credit user mashed potato mac n cheese',
#  'local mp downgrade hospital savethealex',
#  'pretty much best advice ever hydrated zerofucksgiven friday sorrynotsorry liveâ',
#  'model alternative tattoo piercing olde towne bellevue',
#  'sent msg aunt peru told wish grandpa uncle happy father day didnt include dad',
#  'day user best',
#  'work attorney white officer shot philandocastile remove black judge presiding trial',
#  'phil spencer criticizes sony course else would got slapped face sonys huge 40 million dick',
#  'user think sa pretty great canât wait show twodaystogo countdown shhh bringiton',
#  'w user user user cafeexpress stanupcomedy crazyâ',
#  'user trump long history explained 1970s thru 2016 nevermypresident theresistance',
#  'happy mother day ppl',
#  'bff liverpool first stop user flatwhite coffeelovers bestfriends',
#  'love herð',
#  'tom hiddleston akalokieexcuse spelling new jamesbond scaryinthor bestchoicefornewjb ðððð',
#  'watch movie alone',
#  'one think could bit punch ð gameofthrones',
#  'im princess im one princesssadly',
#  'cant wait icon weekend cant wait finally get one tatoos icon16',
#  'laughing fact mfz use app talk u feel inside people see haha',
#  'sterling attack bull chase leave lot despite fact youre strong source fo',
#  'user user user never doubt pa many voted sad america',
#  'cut anyone english dna half well find written inside',
#  'user vip ciniworld caz user ð ð',
#  'seeing war craft imax 3d ð warcraftmovie imax woohoo',
#  'user burnt garlic bread devastated',
#  'user looked right cameraman grabbed katies arm amp said talk wow everything tv',
#  'user user user user user held one march great cpd everyone ðð½',
#  'looking african news boredem stumbled upon user oh god site racist fuck everything',
#  'user user dana devestated hasnt trouble',
#  'gorgeous i_am positive affirmation',
#  'user oh he admitting small staff flipflopper disgraceful',
#  'happy instagram instagood instagram instapasspo instadailyâ',
#  'splashing around ððdogs bestdogever swimming healthy goodvibes yoga fitnessâ',
#  'people old bored resolve bullying others twitter',
#  'user isnt love isnt',
#  'user wasnt much violence last euro wonder happened brutal side coming back euro2016 footbaâ',
#  'messed nail',
#  'selfie srelfie smile selfie followme f4f polishgirl polskadziewczyna',
#  'vera rubin overcame invented whole field scientific study diversityinscience science steam',
#  'user user user user user sorry read much pain',
#  'user draft 1ðð b4 pick ðup uni liverpool recognition user user user',
#  'â gbpusd upside limited around 1425514350 â commerzbank blog silver gold forex',
#  'childrenoftheworld bull dominate bull direct whatever want',
#  'kaya class ðð½',
#  'london ððð selfie smile love photooftheday picoftheday london londonlife user',
#  'need prayer right taking grandma death well shocked whyher',
#  'user user user seen gay gorilla mindset nonsense touting dershowitz clean',
#  'user think going best match ive ever watched wedding oldgirls auwfc',
#  'user user unfounately current gop see reagan like',
#  'monday instagram instagrammers motorspo photographer formula1 user',
#  'great day little man tkd grading amp cracking swimming lesson topped wale win wal',
#  'sorry bear user time',
#  'user cant wait pubcon user bestconference oct16 digitalmarketing comingsoon',
#  'user monday u ð model boob tit urbex television sexy retweet tights pantyhose desire touch',
#  'glad live hereð place ð',
#  'family ð fasting family likeforlike like4like lfl together happiness lovelyâ',
#  'starship nickiminaj 6secondcover singitfohevine singersofvine singing musician music',
#  'user make someone happy today minding damn business life living inv business love',
#  'paradise rooster simulation want climb vast expanse mountain reached leakage cock w',
#  'pats2020 student want snapchat adrianmcqueen snapchat ucumberlands college',
#  'client needed brainstorm socialmedia altrincham',
#  'disney gator attack 2yearold boy found dead disney',
#  'price stolen paymentcard record dropped 25 2011 6 2016 ransomware rise',
#  'got free slice cake fav cafe tgif',
#  'user box pictured contains single inflatable prepschoolboy sexdoll',
#  'user relaxed peaceful âºï',
#  'user first user user new customer user paners drupa2016 hall 10 stand c133',
#  'since last time drank hard liquor officemates',
#  'user older people see pic nose remembers smell close impoant site like',
#  'ð socialmedia may 2016 hottest may record nasa',
#  'say wont able attend user year due hotel cost hope attending next year tho',
#  'hea spazzing shipping hahaha doctor',
#  'nearly ready nohamptoncarnival',
#  'many innocent people die ceain politician choose ignore hate refuse even discus gun control',
#  'almost week since saw stroke',
#  'user sta newbook visit jfk museum inspiration',
#  'fatal truck crash kigali highway leaf 30 people died instantly around kicukiro centre rwanda',
#  'marshmallow time fire son love',
#  'user cant believe much used care people thought im like lol fuck u fuck wtf fuck youâ',
#  'jealous best mother ðð â mamatii je taime ââ cute nice herâ',
#  'always amazes come unexpected place like local cafe today irish got first muslim gutted',
#  'icedcoffee user coffeeblogger coffee thecappuccinotraveler â',
#  'user ever get lyme war yeah help',
#  'p5 pupil ready ymi musical extravaganza',
#  'made laugh hard angry bieber dontknowwhy fridayfun user',
#  'â usdjpy bull sit tight 107 handle fxstreet blog silver gold forex',
#  'user failed terribly controlling drugsmust punished electorallybut user let initiallyno blueð fb',
#  'user user never see store anymore ð asked autograph said hi time iâ',
#  'ðððð rest peace christina rip ripchristina christinagrimmie love miss',
#  'always watch one user racesit inspires trainingstill got solid month yet 1st race',
#  'see picture dog today smile face tweet good',
#  'woke af realize world around isnt changing sigh',
#  'love returnsâïðð¼ð¹ð coollime starbucks cool lime feel fresh nice great drink â',
#  'could worse embarrassed unfounate traumatized bitch black life matter black people',
#  'ð tech buy bitcoins debit card',
#  'happy father day father fathersday sunday family',
#  'user user still fucking bullshit giving bigot platform spread vile hate boyâ',
#  'user girl boy p user user sissy user user user user',
#  'bihday flower saturday flower love jes b jewelry studio',
#  'user user dont even think he wearing dad jean',
#  'another nerd friend ban personal belief whosnotopenminded ohwell',
#  'user user user always race religion thats whats wrong w america',
#  'sometimes take realize person really fit life friend soon bos',
#  'back day job shane lowry gtgt',
#  'fathersday strongest patient kind understanding person knowâ',
#  'third wheeling cold stone right used buy one get one free coupon',
#  'simply assault equal spitting someone authority got charge wrong guy walk',
#  'user get tweet marriage wale',
#  'user 93 video 16 referred sen warren pocahontas stable pattern ignoranceâ',
#  'make meer inspiratie kijk op life',
#  'house taken football time get reading user always love book',
#  'user end day gotta',
#  'cleveland fan look',
#  'user getting ready deliver feature address brighteyed group youngster nervous',
#  'user smoothie glass half full comeon',
#  'wednesdaywisdom make sure ignoring true happiness life',
#  'user trust broken right',
#  'iftar happyhouse âï bestie friend chillin iftar goodtimes tgi friday streetâ',
#  'realized look little cross eyed license lol',
#  'going fun week 10 day csikraken construct',
#  'bihday sweet little mermaid time flown quickly cant believe aâ',
#  '30000 arrest daily usover 160000 policecivilian encounter daily shootingsabuse extremely rarethoâ',
#  'thankful inspiration thankful positive',
#  'wish kpop aists never come country wont able see perform im broke ppl kpop',
#  'want go anywhere sunday since ghosthuntersinternational destinationtruth chillernetwork',
#  'father day ðºð',
#  'people judge colour english accent',
#  '9975 lostnfound got together wanted serious longterm monogamous relationship',
#  'cc without aciiii ð eki liani fetty cc emergency team friend family like love â',
#  'black life matter today day',
#  'â usdjpy remains weak 10600 blog silver gold forex',
#  'character customization confirmed pokemonsunmoon e32016',
#  'user user emma great meeting yesterday email oppounity already',
#  'poor babe missed water play morning school ð figured theyd water play afternoon poorbaby',
#  'let lighthmmm prefer lspotlight ððð vibrant alive joy sparkle',
#  'today good day love goodday smile goodangle instasmile instagramâ',
#  'really terrible mass terrorist attack usa night club àààààà blackday user user user',
#  'user user hear bigotry homophobia sexual assault womanizing treason lie hearâ',
#  'right one suppos woman nutrition romance love dating soulmates sexy',
#  'hate crisis among many others president elect user amp co capable',
#  'user wonderful saturday flower day ðððððºð vine user',
#  'im guessing chip hill doesnt teach kid spell mp might little hard u ð',
#  'ive got wine vhappy',
#  'user deserve much better understand endorsing stand much',
#  'user thank reaching issue resolved turn site isnt fully compatible safari io macos',
#  'happy bday jb yesterdaycelebration fambam â feeling happy',
#  'bihday libation ð feat user gay boy cute friend love â',
#  'user user bihday majesty',
#  'sleeping cryingð',
#  'user live colorcheck new tote bag color lifetotebag inspiration htâ',
#  'thank much user really feel amazing',
#  'user pimp hoe hooker point documentary brent owen cathouse series kid lol',
#  'goomespa divulgaããoeparceria inshot girl cute summer blur sun fun dog hairâ',
#  'sad true true',
#  'animal cat cat grumpycat happycampers treat ill play',
#  'aww poor ednahhthepug missingmommy sitting wait timeâ',
#  'nice delivery today manfrotto peakdesign photo photography tripod strap bag user',
#  'smile filter instamood picoftheday behealthy summer bliss bitchplease',
#  'preordered user 3d browtones im beautyblogger icantwait',
#  'user luther vandross dance father father day',
#  'enslavement animal okay',
#  'dark',
#  'ah man sunday cant come round quick enough thestoneroses ð',
#  'got first user liquid lipstick love ð girl',
#  'first bubble 40yr old self champagne celebrate thanks pete gemini bihday indeed',
#  'user patriotwatch 411 sherm new year gap auspol rwnj drunk refugee asylumsâ',
#  'user accept fact apple lost innovation staed ripping android',
#  'shocking ampvery hear christinagrimmie past awaymy thoughtsamp prayer rwith family time ripchristina',
#  'user hey user love music really youre performing murderous azerbaijan dictatorship',
#  'new ted_baker ski top surprise hubby lucky loa lawofattractionâ',
#  'user love ðð hello kitty ððð model pink girl girly yolo smile pop â',
#  'user user ur gunna miss',
#  'meeting today volunteering run user local library went kid givingback pocintech',
#  'whenever youre sad close eye remember happiest moment life life lifequote thought',
#  'user cant wait see iron maiden first time next sunday user',
#  'user never previous secretscreenings starmoviessecretscreening shh coming ð½ðððð',
#  'mikoto suoh ðð kproject mikoto vine cassidytheduck',
#  'thought factory leftright polarisation trump uselections2016 leadership politics brexit blm gt17',
#  'user user user user user ð¾ðð¾ sunday ð¾ðð¾',
#  'user biography stepcousin denise got ear mite using payphone',
#  '4 ðððð memerry behappyandsmile behappyandsmilealways behappywithme likesmeâ',
#  'user tgif ff gamedev indiedev indiegamedev squad user user user user user user',
#  'user go eat shit dog antiamerican piece shit bet dad fucked mouth trump nazi',
#  'really happy graduated childish shit graduation done',
#  'would living life grateful compassion love one another withoutâ',
#  'many hash tag ðð',
#  'huaweiceifiedspecialistpresalesaccessnetwork delivered yes stress snoâ',
#  'looking forward user bean caramel macchiato definitely burnt membury service ð',
#  'user user ohmyword dont think shes aware ghastly there something broken soul needsâ',
#  'user tap gratitudejournal benefit without journalentrypressure gratitâ',
#  'user user suppose confirms user cant even read teleprompter',
#  'great user screw job 2016 user cannot catch break impactonpop impactwrestling',
#  'user tomoz nite user hitting stoke going fab night glad im going bestie user 3rdrâ',
#  'last formteachers lesson byebye8year',
#  'care ðð dont care alone',
#  'way door county wisconsin weekend vacation car foreverdrive indy traveling vacatiâ',
#  'user poor world',
#  'realized laker fan make u hate every western conference team cant root 4 dub impetty lakers2017 kobe',
#  'mind boggling dontunderstandtheconswquences',
#  'user like true false stephen keshi die na waohthis life eh one thing dey rememba abt say dey alwaz chew gumâ',
#  'trigger impulsive decisioning strike haha netherworldforess tier 1â',
#  'always ministradesanidad',
#  'user user user single word required waste everything wha actually _',
#  'user mercury engineering amp mercury cloudcover truly attend prestigious event data datacentre',
#  'cant always always positive inspirational user gepaforum',
#  'user tbt capetown tablemountain dad ghel bakhe ð bihday lafamilia âïâºï',
#  'new tenant collecting key 9am user propeyhants moving apament',
#  'user see u soon user stratton u attending come find u wanderlust fashion',
#  'think happy stay happy',
#  'user cant wait join u garden walk user',
#  'yes today day user im getting giddy ðð orangeisthenewblack season4 obsessed',
#  'user slfl conce week away x',
#  'saturday people hopefully youre hungover listen newsong band unsigned',
#  'recognize amp acknowledge relationship ð god give need succeed â',
#  'booked ticked see chas amp dave user cant wait user',
#  'wonder wifi doesnt work anymore wifi wifiproblems wifioverload wifisucks suck networking',
#  'idea stupid comment make inviting response death sideshow',
#  'check user daddydub super father day u 1 best father 4 gr8t',
#  'black life matter group black extremist',
#  'rainy day blue got get fishtacos wednesdaywisdom manhattan lunchbreak dontworrybehappy',
#  'good news digitalmarketing campaign use facebook ppc extremely annoying 20 rule socialmedia',
#  'first ever time government building oireachtas leinsterhouse dublin parliment â',
#  'thrillingi_am positive affirmation',
#  'would like thank people following really appreciate author novel writerslife book sciencefiction creativity',
#  'user user yeieee jito ya haro bt ur gang already wo million hea fir bhi hope aapka gang jeetey',
#  'make choice better self selfimprovment betterlife anxiety happier struggle behappy',
#  'user youre typical ghetto po politician refusing take painting cop porayed pig federal bldg',
#  'new addition newaddition fbloggers',
#  'thankful transpo thankful positive',
#  'latest knitting clio daily thanks user user user twitterstorians',
#  'keeping company borderjack cuddle',
#  'user user love ron definitely wethepeople rank amp file complacency worst',
#  'father day âï samsung galaxy s7 ð shakeys usa',
#  'user hello 1418pm warm oman ðð see share sunshine user ðððð',
#  'summeime gorilla simulator need adapt environment need tear city mate',
#  'lesson happiness life via user',
#  'got nothing word weeping orlando heabroken',
#  'nope uncle buster sound like jerk trumpsamerica',
#  'looking old user harrypotter user expensive 200 small set already open used sodisapointed',
#  'nice user user ready user coming oakland marijuana business boom california',
#  'u rip front bumper mazzi curb day buddy',
#  'girlz wanna fun ð girl baby love selfie â',
#  'easter meanwhile white house',
#  'weekend sho amazing time friend family summerishere lovedthisweekend',
#  'user little known fact miller lite ped list lbjdrinksonlyjuice',
#  'user user cause lost',
#  'still woman wow',
#  'user first day new diet gone well nice healthy salad tea im relaxed productive starâ',
#  'okey know latest tweet bit clitchy hey like u dont dont care ð idontcare',
#  'brutality rule new year manus close manus auspol australia refugeeswelcome noborders',
#  'find awesome shi sho broad user wasnt one',
#  'staed reading last day first signing summer',
#  'user sad guy killing warrior team soon',
#  'user agree time change tune floor vote user user user user',
#  'tbt age sixteen success positive quote choice kindness love thursday winningâ',
#  'father day love dad may live long ameennn lifeee',
#  'user tweet serious ð still comment',
#  'user user user user ððð saturday',
#  'coolestlifehack brazilian gold frog smallest frog motivation',
#  'user coming soon amazon coloringbook oliviagraceowens',
#  'chatter girl guided chocies alicia marcos birong radio sholy click link',
#  'horse maximus',
#  'littlest thing make ð',
#  'user cant believe man jose followed hope guy crush baltimore tonight â¾ð joeybats longball',
#  'en route happy mondayâððâ iâïmondays freshsta newweek newme glassalwaysfull',
#  'âïâ ïâïâ ïfrobabies frobaby naturalhair babyfever melanin love øùù family cuteâ',
#  'nakedbusty user user user love much user user user',
#  'shes think shes beautiful tricoloredamericanbully bluetri pitbull baby',
#  'pilate perfect sunday kxpilates getfitordietrying boomerang kx pilate hampton',
#  'god see u wan hype father day smh',
#  'said b4 world encashing whereas india loosing legacy due bickering amp politicisation yoga',
#  'photo last year',
#  'gotta love staffy doglover mansbestfriend',
#  'brisk_and_vagabondnight_and_dayz__black_mambang049web2005ukhx_int next generation web hardcore â',
#  'user thanks managed',
#  'user user good morning dearo saturday',
#  'honored present user three megratrends intl student mobility aiec2016',
#  'thing worse putting word mouth dead people taunton hitchens atheism',
#  'spring green latest auspol election16 news friend victorian green springst auspol',
#  'instracistclown meme instagram funnypics nochill funnymemes chill 100 deâ',
#  'say dad made better dad say dad gave brother amp niecenephew',
#  'user kid afraid go wait',
#  'dishwasher original drawing ð',
#  'see new webpage orlando file goodread goodbook bookclub top10 medicalthriller',
#  'see ritzparis reopened lhw showcase amazing evening royalpalmmarrakech bchotelsâ',
#  'playing game joke',
#  'playing joe bongiorno mystical music song',
#  'hope wonderful weekend monday good sta weekâ',
#  'summer seemed last forever summer walk sunny magical beautiful nature skyâ',
#  'try something good always end feeling like shit hating',
#  'goodmorning uk today world need love hate le peace smile',
#  'user gonna stop trying grow beard give rest leave pro',
#  'bihday favourite brit awesome time bbqing drinking thisâ',
#  'tomorrow sta planning niece nephew baby shower ððð',
#  'looking forward user repo ccm due publication month',
#  'thoughtcast sac 00026 photooftheday music instamood photography instadaily nike family design',
#  'user absolutely pathetic user cant trusted',
#  'user right 2 without stress fear human right shouldnt living ððð',
#  'amazing day surprise movement',
#  'caffeine fix quick cup coffee positivity appreciate friend love creativeâ',
#  'green jamesmcavoy atonement mcavoy flim',
#  'pas last exam made new lash thanks studiia_lakshmi ð studentâ',
#  'user easter new hero',
#  'user peace love ooh ooh brighton woopwoop busker drummer kidsdrummer brightonâ',
#  'user user bonne fãªte jeff bihday happy bihday jeff happy bihday happybihdayyhâ',
#  'god help parent lose child antonyelchin',
#  'somebody tell user thepeople didnt chose user hispeople choose trump big difference',
#  'awesome humpday vibe wellbeingwednesday morning motivation',
#  'winner harriet sturgess receiving iow festival ticket winner domino',
#  'put tear muslim muslimwomen islam america americanignorance',
#  'word factory race denial prevents healing southafrica leadership transformation inequality gt5',
#  'user badventcalendar day24 â nov 8 trump election2016 donate fkin save 2016ð',
#  'happy father day daddy daughter dance sweet love dad fathersday user',
#  'fed provide inadequate mentalhealth care firstnations internal memo thirdworldcanada',
#  'latest unsw daily thanks user user ocean',
#  'well yvr pa time head back real life yow great trip overall much done ellatravels hotweather',
#  'old guy sleep safe amp',
#  'happy friday âïâ shot ó¾ user blog blogged blogger friday fashion style',
#  'father day amazing daddy amazing fiancãloadz love kim mark nd morgan xxxxxxx',
#  'user happiness joy sorry deepak follower love brief release',
#  'bestseller user motivation never go bed without dream wakeup without hope',
#  'healthy lunch go ðððð botanical nutrition skincare healthâ',
#  'user user time going make political',
#  'user much appreciated dear probably issue wrong timing thanks suppo standard',
#  'user happy place smile inspire',
#  'user preorder user playingitmyway autobiography available nov 6th exâ',
#  'resilience capacity recover quickly feeling deflated dont beat self past stay',
#  'new diary dairy love write amazing lovely quote wordsofwisdom word happinessâ',
#  'there site lt3 freedom isi ignorance amp selfloathing theyre sick bunch',
#  'user user user oh boywhere sta unattributed dependant innuendo fearbaiting weak rallying cry',
#  'love friday ilovecarnivalseries hour weeekend fridaychil chilln',
#  'another sneakpeek final preparation user next week',
#  'user user myopic guess money mean people need leave coaching forever 1 year',
#  'im really quick 20 minute flower painting love old palette soâ',
#  'user good old fashioned public shaming order',
#  'user user sure sleep w follow every lap know user fav',
#  'refuse bake cake conviction get convicted cou sell aboed baby pa amp get rewarded',
#  'life right im blessing oppounities career',
#  'everybody necessarily want admit liked gej ashamed associate wt',
#  'live carnaby store seen anyone onion kitchenlife',
#  'sat watch user',
#  'twitter kind recently going ignored',
#  'cook book coming soon chef b lander sharing hit recipesð privatechef â',
#  'actual argument hatred rm reso name calling raider',
#  'architecture attack bull game 3d really think head empty around city side',
#  'cutie ð fun manly sydney hugo friend sydneywinter beer laughsâ',
#  'need sleepyou laughter antidote depression',
#  'great waiting long finally get join payd wale togetherstronger bbceuro2016',
#  'close booked wedding date cannot wait share picture u beautifulhighbarn',
#  'one week exactly ill edc',
#  'user 14th amendment blm discussed thanks user',
#  'cant find fob poster decorating room poster falloutboy alltimelow 5sos',
#  'bob marley sang song humanity youth th day knw coz used smoke weed',
#  'user utterly disgraceful parent dealing unimagineable tragedy internet cant help',
#  'back work kinda lazyday routine ðð lazy lazyday friday fun foodâ',
#  'user hope u guy ready requested user rage callofduty gaming youtube ragenation',
#  'time tomorrow user get see user',
#  'dont say weve got love instagood tbt follow cute photooftheday followme',
#  'officially unemployed hahahaha ð greatful blessed graduationdayð',
#  'say user exclusive mix ditch label dropping next week',
#  'user lt3 listen beautiful best friend user singing amazing voice lt3 lt3 lt3 lt3 13',
#  'get fit summer aomagazinede fitness model girl hot beautiful sexy love cute summer fun',
#  'imagine grown man wanting hooligan',
#  'delicioso ð6ïâððâïâïâïâïinstamoment instafollowers instaiqq instaiquique loveâ',
#  'challenge aaps claim 70 punjabi drugaddicts dare prove',
#  'ððªð crgmm grammy official à¹ààà today vedio mv music feelgood like like4likeâ',
#  'healthandfitness attack bull game 3d really think head empty around city',
#  'r musician horrible w grammar dont teach grammar music school',
#  'brooke stallion baaaaack welcome stay please brill',
#  'user agree sentiment im orlando neverpolitical bouncing wall furious impotent despair worstopost',
#  'sale piece day prince ceramic plaque reg 23 today 18 ó¾ easel reg 15 today 10 father day',
#  'â audusd sell rally 07480 â westpac blog silver gold forex',
#  'love life im lucky give thanks fact often',
#  'good night faith ever vaitacacommafiasdv',
#  'old oldfashioned love cool perfect nice crazygirl smile card oldschoolâ',
#  'user good way protect user account activate 2fa bad doesnt work germany user fix â',
#  'mine cider weather',
#  'im sadððððððððððððððððð lost soccer game penalty kick bad call badref soccer',
#  'user safe flight anak may god protect throughout journey',
#  'cant even orlando notagain',
#  'week rehearsal sinkthepinkfreakshow finally hereâ user',
#  'stay grandma help surgery 2day crazy plus without internet',
#  'rosie redfield next mgcb user',
#  'woohoo hotel booked user brew amp bbq little excited try amazing menu',
#  'ready schoolðð firstday collegelife',
#  'queue',
#  'life simple happy laugh sad smile always',
#  'zealous i_am positive affirmation',
#  'user user one day 2611 3 day u made terrorist attacked india three daysimagine indâ',
#  'bihday licor cafã ððð',
#  'thanks memory bungie think im done destinythegame noriseofiron x360 make',
#  'user mock citizen immigrant worked hard earn citizenship wow take benefit freedom mock',
#  'trump ally made remark towards obamas cnn carlpaladino',
#  'user got place done user 3 time plus 3 user marathon never london goals2017',
#  'beautiful cornwall timeaway peace countryside timetothink calm water greenâ',
#  'despite setback shaping good month anticipation',
#  'bird look cool hell ax kid drawing 6 year young',
#  'user user black folk become enemy oppressor wonder chimurenga woh',
#  'enjoying sunday relax âïâïð mallife coffee sundayfun relaxing â',
#  'sound like user hate 1st amendment thinskinned crybaby',
#  'thando thabethe bae bdae mem user',
#  'madashell join',
#  'father day frnds',
#  'user user didnt take long',
#  'trump medium normalizing kkk alternet',
#  'playing karen marie garrett daydream melancholy melancholymusic',
#  'van jones try walk back white lash remark trump suppoers tcot',
#  'goodmorning sunday like4like likeforlike happiness morning selfie trytobebetterâ',
#  '20160611 todaydesneyseafriendsunny tired',
#  'one like option someone else clear sore euro2016 spain smile',
#  'enjoying russian rock music cleaning kitchen making popcorn lemonade yes 200am est',
#  'user election difficult gop considers po dem dems considers po dem facing denies',
#  'today sta thought ððâºïðð lot positive thinking plan today',
#  'fine williams non relevant',
#  'heading gulliver first fencing competition user user user epee welshfencing',
#  'ð via user goodenough healthy holistic yoga gestalt therapyâ',
#  'happy anniversary crisafullis',
#  'user also leave man card',
#  'user know youre user register amp could meet sultan beingsultan',
#  'want holy wholly committed god result greg laurie',
#  'n healthy flower everywhere bother look â henri matisse',
#  'mmmmm understand corn icecream edm edc beat club dj djlife waitfohedropâ',
#  'user user user user user feel see wife passing home 50 yr',
#  'super fun day set ðó¾ó¾ lovethiscrew evokeproductions servin old schooló¾ photooftheday fun',
#  'loved happy hour user amazing cocktail brixton love âïâïðð',
#  'gt bihday special day say bihday u great price',
#  'user sta day right âïðð â â â â happiness optimism positive positivity loveâ',
#  'user user user listening fbi director seems though get talking point obama',
#  'dont see gay lesbian trans murdered see human beeing slayed others human orlandoflorida',
#  'awesome weather awesome journey world heritage kalka_shimla toy train ðð ð user feeling life family',
#  'sparkling i_am positive affirmation',
#  'user spec belong u baby smile magpie glass',
#  'sad lovewins fightback orlando fuckhaters',
#  'al fin âð½ï viernes meesperaunplanazo ganasdeviernes ganasdeti friday modoon â',
#  'user wake smile tell today day tuesday felizmaes flower flower spring g',
#  'eat healthy live healthy everyday ðfixwhatsbrokenin5words eathealthy live healthy body mind soul spirit',
#  '5 quick fix improve mental health tip life',
#  'user good luck champ well cheering always',
#  'user got meet user user cant wait hear sing great way sta weekend music',
#  'user thank ð santa ð best christmas present ever cdnpoli abpoli yyc yeg canada ottawa user',
#  'happiness anyone 15 little choice make user',
#  'here flower rainy day ð london britain weather flower vibe',
#  'racism u amp netanyahu commitment genocide explain bbcnews msnbc npr cnn wsj huffpostpol nyt wapoâ',
#  'hereamp039s movie playing weekend lancaster county lancasteronline',
#  'happy father day great dad nascar year happy father day dale earnhar',
#  'tygtuser user user user user user user midweekâ',
#  'happy day ð',
#  'see video 2013 alligator sighting walt disney world coronado spring reso grandfloridian gator orlando',
#  'user bluntly tweet cologne police user announces racial profiling main station wow',
#  'spectrump king led unveal brightest led world led cannabisgrow',
#  'user user let go ok',
#  'representing boingos mediaplatform hitecnola next week monetizewifi wifi hitec digital',
#  'charming i_am positive affirmation',
#  'much',
#  'day 44 finally get meet msyee morning even though onlyâ',
#  'baby strawberry âïðð½ð texasstrawberriesarebigger',
#  'user grow dinosized cave cricket amp wolf spider tho 9 hu7i',
#  'user â³ïsunday morning classic playing clubhouse lovely smelling coffee âï member sunday fathersday',
#  'tuesday hows going dead flipflip rip cbs radio',
#  'special delivery going p7s tomorrow graduationball farewellclassof2016 ticket',
#  'best gift god ever blessed im grateful ðð blessed inlove gratefulâ',
#  'sex video sexy lady fucked hard pic',
#  'thinking old friend unfounate circumstance today sending love good wish hope future',
#  'genuinei_am positive affirmation',
#  'suck single loyalfaithfull girl get husingle',
#  'picked overwatch pc battlenet id chillmaster 11180',
#  'user user yet make see tuesday headedtoe3',
#  'saibabas day devotee user om sairam',
#  'user user user u gun law thats',
#  'monent soldier familyso country',
#  'already hit trail tomorrow nbjc jeeplife jeepmafia jeepnation jeepgirl',
#  'crazy hdrfusion dope lose game gt',
#  'telling old story friend bring back good bad memory warstories stilldead',
#  'user kudos compliant itaxnirahisi proud taxpayer',
#  'father day dont one',
#  'user ceainly 1a tipping point country',
#  'witnessed 8 year old grandmother tear huful word',
#  'user wine wed user wine cellar vineyard family heritage wed drink hunter â',
#  'jb3mama rolewhere r uim ss1imwith_usee kettlesmilemy sun jb3i knowuampi sadshahadaampup fri',
#  'saturday pay hawaii collar drink pay saturday sunnyday friend luv gfâ',
#  'every man want order need first understand happiness',
#  'since 1965 voting right act dems blaming republican 4 biggots new buzz word racist',
#  'fashiondiaries bull dominate bull direct whatever want wh',
#  'want photo user smile live model babesinabathtub lamodeâ',
#  'isnt bgampe2 ubie3',
#  'daddy girl âºâºâº father day',
#  'takeaway ordered ðð',
#  'user obama amp hillary divided america arrest made burning black church black suspect arrestedâ',
#  'omg sad user dead cant understand shit fly away angel rest peace ððð idol ripchristina',
#  'michelle obama âape heelsâ case beginning donaldtrump america',
#  'im shock loss great talent hea break usa',
#  'user punjab green revolution drug revolution couesy akali congress ààà àà ààà ààà² àà¹à¾ à¹à à udtapunjab',
#  ...]

# %% [markdown]
# **Consider words with lengh greater than 5 and plot**

# %%
large_words = dict ([(k, v) for k, v in frequency_dist.items () if len (k) > 5])
frequency_dist = nltk.FreqDist (large_words)
frequency_dist.plot (50, cumulative = False)

# %% [markdown]
# **Build wordcloud**

# %%
from wordcloud import WordCloud
tcloud = WordCloud ().generate_from_frequencies (frequency_dist)

# plotting the wordcloud
import matplotlib.pyplot as plt
plt.imshow (tcloud, interpolation = 'bilinear')
plt.axis ("off")
(-0.5, 399.5, 199.5, -0.5)
plt.show ()

# %% [markdown]
# **Building a text preprocessing pipeline**

# %%
# read the data
dtweet = pd.read_csv ('../input/twitter-sentiment-analysis-hatred-speech/test.csv')
dtweet = dtweet ['tweet']

# %%
# write the function to process the tweets
def processRow (row):
    import re
    import nltk
    from textblob import TextBlob
    from nltk.corpus import stopwords
    from nltk.stem import PorterStemmer
    from textblob import Word
    from nltk.util import ngrams
    import re
    from wordcloud import WordCloud, STOPWORDS
    from nltk.tokenize import word_tokenize
    
    dtweet = row
    #lower case
    dtweet.lower()
    #removes unicode strings like '\u002c' and 'x96'
    dtweet = re.sub (r"""(\\u[0-9A-Fa-f]+)',r""", dtweet)
    dtweet = resub (r"""[^\x00-\x7f]', r""", dtweet)
    # conver any url to URL
    dtweet = re.sub("""(www\.[^\s]+)|(htpps?://[^\s]+)""", 'URL', dtweet)
    # convert any @Username to "AT_USER"
    dtweet = re.sub("""@[^\s]+""", 'AT_USER', dtweet)
    # remove additional white spaces
    dtweet = re.sub ("""[\s]+""", ' ', dtweet) 
    dtweet = re.sub ("""[\n]+""", ' ', dtweet)
    # remove not alphanumeric symbols white spaces
    dtweet = re.sub (r"""[^\w]""", ' ', dtweet)
    # remove hashtag in front of a word """
    dtweet = re.sub (r"""#([^\s]+)""", r"""\1""", dtweet)
    # replace #word with word
    dtweet = re.sub (r"""#([^\s]+)""", r"""\1""", dtweet)
    # remove :( or :)
    dtweet = dtweet.replace (""":)",""")
    dtweet = dtweet.replace (""":(",""")
